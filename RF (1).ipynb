# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

import sklearn.metrics as sk
import matplotlib.pyplot as plt
from itertools import cycle
#import pydot
import io
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-790508aaf58a> in <module>()
#       6 import matplotlib.pyplot as plt
#       7 from itertools import cycle
# ----> 8 import pydot
#       9 import io
#      10
#
# ModuleNotFoundError: No module named 'pydot'

# %%
Ami_data = pd.read_csv("E:\\dataset.csv")
Ami_data = Ami_data.sample(frac=1).reset_index(drop=True)
Ami_data.head(5)
length = Ami_data.shape[0]


x_data = Ami_data[['Age','Gender','Hypertension','Hypertension_medicine_years','Diabetes','Diabetes_medicine_years','Cholesterol','Cholesterol_medicine_years','Smoking','Family_history','Chestpain','Symptoms_Except_Chestpain_(Giddiness)','Symptoms_Except_Chestpain_(Nausea)','Symptoms_Except_Chestpain_(Sweating)','Symptoms_Except_Chestpain_(Syncope)','Chestpain_location','Chestpain_mark','Pain_going_(Left arm)','Pain_going_(Right arm)','Pain_going_(Back)','Pain_going_(Upper jaw)','Association_(Dyspnea)','Association_(Giddiness)','Association_(Nausea)','Association_(Palpitation)','Association_(Sweating)','Association_(Syncope)','Association_(Vomiting)','Doing_while_started','Persistence','Pain_relived','Subsided','Pain_type','Similar_pain/chest_discomfort_in _past','After_drinking_water_pain','After_having_food_pain','By_chest_movement_pain']].values
y_data = Ami_data[['Heart_attack','Maybe_heart_attack','No_heart_attack']].values

y_test = y_data[222:]
Ami_data.head(10)
# Out:
#    Unnamed: 0  Serial no  Age  Gender  Hypertension  \
# 0         159       1135   70       5           2.0
# 1         206        515   57       4           2.0
# 2         143        551   18       5           2.0
# 3         299       1165   45       4           2.0
# 4         256        537   31       4           3.0
# 5         146        606   19       4           3.0
# 6          92       1145   48       5           2.0
# 7         129        502   57       4           3.0
# 8          20       1148   55       4           3.0
# 9         249       1177   35       4           3.0
#
#    Hypertension_medicine_years  Diabetes  Diabetes_medicine_years  \
# 0                     5.000000       2.0                      6.0
# 1                     2.000000       3.0                      3.0
# 2                     4.482143       3.0                      3.0
# 3                     7.000000       3.0                      3.0
# ...

# %%
ran = RandomForestClassifier()
rfc = ran.fit(x_data[:221],y_data[:221].ravel())
scr = ran.score(x_data[222:],y_data[222:].ravel())

y_pred = ran.predict(x_data[222:])

print('Random Forest Classifier\n__________________________________')

confusion_matrix = sk.confusion_matrix(y_data[222:].ravel(), y_pred)
sensitivity = confusion_matrix[1,1,1]/(confusion_matrix[1,1,1] + confusion_matrix[1,0,0])
specifity = confusion_matrix[0,0,0]/(confusion_matrix[0,0,0] + confusion_matrix[0,1,1])

print('Accuracy: ',scr)
print('Precision: ',sk.precision_score(y_data[222:].ravel(), y_pred, average="macro"))
print('F1 Score: ',sk.f1_score(y_data[222:].ravel(), y_pred, average="macro"))
print('Sensitivity: ', sensitivity)
print('Specifity: ', specifity)
print('Confusion Matrix: \n', confusion_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-873d6f2b987e> in <module>()
#       1 ran = RandomForestClassifier()
# ----> 2 rfc = ran.fit(x_data[:221],y_data[:221].ravel())
#       3 scr = ran.score(x_data[222:],y_data[222:].ravel())
#       4
#       5 y_pred = ran.predict(x_data[222:])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     324                     t, self, X, y, sample_weight, i, len(trees),
#     325                     verbose=self.verbose, class_weight=self.class_weight)
# --> 326                 for i, t in enumerate(trees))
#     327
#     328             # Collect newly grown trees
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
# ...

# %%
# Compute ROC curve and ROC area for each class

y_pred = dtc.predict_proba(x_data[222:])

fpr[3], tpr[3], _ = sk.roc_curve(y_data[222:], y_pred[:,1])
# print(fpr[3])
# print(tpr[3])
roc_auc[3] = sk.auc(fpr[3], tpr[3])



fig = plt.figure(figsize = (15,10))
lw = 2
plt.plot(fpr[3], tpr[3], color='green',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[3])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for Random Forest')
plt.legend(loc="lower right")
plt.show()

fig.savefig('Receiver operating characteristic for Random Forest')
